# %% [markdown]
# # TASK1

# %%
import nltk
def gender_features(word):
  return {'last_letter':word[-1]}

# %%
gender_features('Winston')
# Out:
# {'last_letter': 'n'}

# %%
nltk.download('names')
from nltk.corpus import names
labeled_names=([(name,'male')for name in names.words('male.txt')])+([(name,'female') for name in names.words('female.txt')])
# Out:
# [nltk_data] Downloading package names to /root/nltk_data...
# [nltk_data]   Unzipping corpora/names.zip.

# %%
import random
random.shuffle(labeled_names)
print(labeled_names)
# Out:
# [('Colette', 'female'), ('Minette', 'female'), ('Kenyon', 'male'), ('Lothar', 'male'), ('Teodoro', 'male'), ('Raymond', 'male'), ('Fiann', 'female'), ('Harlin', 'male'), ('Gilberte', 'female'), ('Ellen', 'female'), ('Danya', 'female'), ('Marrilee', 'female'), ('Harmonia', 'female'), ('Neely', 'female'), ('Bettie', 'female'), ('Waine', 'male'), ('Johnette', 'female'), ('Giraldo', 'male'), ('Loralee', 'female'), ('Hayden', 'male'), ('Osbert', 'male'), ('Natalina', 'female'), ('Tharen', 'male'), ('Cristabel', 'female'), ('Diannne', 'female'), ('Briney', 'female'), ('Bambi', 'female'), ('Giselle', 'female'), ('Quincey', 'male'), ('Durant', 'male'), ('Beverie', 'female'), ('John-David', 'male'), ('Spense', 'male'), ('Vale', 'male'), ('Spiros', 'male'), ('Allsun', 'female'), ('Cindy', 'female'), ('Amabelle', 'female'), ('Brooks', 'female'), ('Modestia', 'female'), ('Odelle', 'female'), ('Moyra', 'female'), ('Salomo', 'male'), ('Berty', 'female'), ('Darth', 'male'), ('Mona', 'female'), ('Chery', 'female'), ('Ashton', 'male'), ('Carlye', 'female'), ('George', 'female'), ('Maryanna', 'female'), ('Velvet', 'female'), ('Clarke', 'male'), ('Parwane', 'female'), ('Celestyn', 'female'), ('Lou', 'male'), ('Karly', 'female'), ('Frances', 'female'), ('Karine', 'female'), ('Desmund', 'male'), ('Kelila', 'female'), ('Kiah', 'female'), ('Alexandrina', 'female'), ('Rog', 'male'), ('Caritta', 'female'), ('Wileen', 'female'), ('Shelbi', 'female'), ('Con', 'female'), ('Archibald', 'male'), ('Dorian', 'female'), ('Madalyn', 'female'), ('Morrie', 'male'), ('Kelsi', 'female'), ('Paddie', 'male'), ('Iseabal', 'female'), ('Pauline', 'female'), ('Frans', 'male'), ('Clo', 'female'), ('Liana', 'female'), ('Benny', 'male'), ('Erika', 'female'), ('Julio', 'male'), ('Harri', 'female'), ('Arlo', 'male'), ('Rosabella', 'female'), ('Darrin', 'male'), ('Anallise', 'female'), ('Vilhelm', 'male'), ('Theobald', 'male'), ('Latisha', 'female'), ('Ivie', 'female'), ('Renato', 'male'), ('Cilka', 'female'), ('Roddie', 'male'), ('Gunter', 'male'), ('Marcelo', 'male'), ('Eleonora', 'female'), ('Howie', 'male'), ('Dyana', 'female'), ('Leonore', 'female'), ('Dyson', 'male'), ('Rollo', 'male'), ('Brian', 'male'), ('Salomon', 'male'), ('Emiline', 'female'), ('Brunhilde', 'female'), ('Patrice', 'male'), ('Marilyn', 'female'), ('Christian', 'male'), ('Lishe', 'female'), ('Madeleine', 'female'), ('Britte', 'female'), ('Minny', 'female'), ('Lorena', 'female'), ('Shoshanna', 'female'), ('Zarah', 'female'), ('Karlie', 'female'), ('Kippy', 'female'), ('Garth', 'male'), ('Cesya', 'female'), ('Julius', 'male'), ('Hetty', 'female'), ('Ollie', 'female'), ('Quent', 'male'), ('Florian', 'male'), ('Krista', 'female'), ('Margaretta', 'female'), ('Yevette', 'female'), ('Merill', 'male'), ('Gretchen', 'male'), ('Joice', 'female'), ('Philippine', 'female'), ('Moina', 'female'), ('Gillie', 'female'), ('Nicholle', 'female'), ('Willie', 'female'), ('Glori', 'female'), ('Charlena', 'female'), ('Leroy', 'male'), ('Lissi', 'female'), ('Silvanus', 'male'), ('Vikki', 'female'), ('Letisha', 'female'), ('Tessa', 'female'), ('Heloise', 'female'), ('Salvidor', 'male'), ('Lilian', 'female'), ('Hezekiah', 'male'), ('Darleen', 'female'), ('Krystalle', 'female'), ('Nikki', 'male'), ('Carley', 'female'), ('Emylee', 'female'), ('Anette', 'female'), ('Kesley', 'female'), ('Camilla', 'female'), ('Brice', 'male'), ('Joli', 'female'), ('Clarence', 'male'), ('Allie', 'male'), ('Lazaro', 'male'), ('Farand', 'female'), ('Hill', 'male'), ('Cori', 'female'), ('Madelene', 'female'), ('Tyson', 'male'), ('Roxi', 'female'), ('Cyril', 'male'), ('Morganica', 'female'), ('Hobart', 'male'), ('Nelsen', 'male'), ('Giffer', 'male'), ('Jasper', 'male'), ('Silvio', 'male'), ('Frederica', 'female'), ('Myke', 'male'), ('Hirsch', 'male'), ('Georgia', 'female'), ('Heinz', 'male'), ('Torey', 'female'), ('Agathe', 'female'), ('Terencio', 'male'), ('Adolpho', 'male'), ('Englebert', 'male'), ('Srinivas', 'male'), ('Swen', 'male'), ('Woochang', ...

# %%
featuresets = [(gender_features(n),gender) for (n,gender) in labeled_names]
featuresets[:10]
# Out:
# [({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'o'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'n'}, 'female')]

# %%
train_set, test_test = featuresets[500:], featuresets[:500]

# %%
import nltk
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
classifier.classify(gender_features('Venkat'))
# Out:
# 'male'

# %%
print(nltk.classify.accuracy(classifier,test_test))
# Out:
# 0.77

# %% [markdown]
# # TASK2 - TWEET TOKENIZER

# %%
import nltk
from nltk.tokenize import TweetTokenizer
text = 'The party was sooo fun :😆 #superfun'
twtkn = TweetTokenizer()
twtkn.tokenize(text)
# Out:
# ['The', 'party', 'was', 'sooo', 'fun', ':', '😆', '#superfun']
